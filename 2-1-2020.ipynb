# %%
from mpl_toolkits.mplot3d import axes3d

# %%
from matplotlib import style

# %%
style.use('fivethirtyeight')

# %%
a=[1,2,3,4,5]
b=[5,6,7,8,9]
c=[4,5,6,7,8]

# %%
import matplotlib.pyplot as pt

# %%
style.use('fivethirtyeight')
fig=pt.figure()
x=fig.add_subplot(111,projection='3d')
a=[1,2,3,4,5]
b=[5,6,7,8,9]
c=[4,5,6,7,8]
x.plot(a,b,c)
x.set_xlabel('x-axis')
x.set_ylabel('y-axis')
x.set_zlabel('z-axis')
# Out:
# Text(0.5, 0, 'z-axis')

# %% [markdown]
# ### Seaborn

# %%
import seaborn as sns

# %%
sns.get_dataset_names()
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\utils.py:376: UserWarning: No parser was explicitly specified, so I'm using the best available HTML parser for this system ("lxml"). This usually isn't a problem, but if you run this code on another system, or in a different virtual environment, it may use a different parser and behave differently.
#
# The code that caused this warning is on line 376 of the file C:\ProgramData\Anaconda3\lib\site-packages\seaborn\utils.py. To get rid of this warning, pass the additional argument 'features="lxml"' to the BeautifulSoup constructor.
#
#   gh_list = BeautifulSoup(http)
# ['anscombe',
#  'attention',
#  'brain_networks',
#  'car_crashes',
#  'diamonds',
#  'dots',
#  'exercise',
#  'flights',
#  'fmri',
#  'gammas',
#  'iris',
#  'mpg',
#  'planets',
#  'tips',
#  'titanic']

# %%
df=sns.load_dataset('tips')
df.head(10)
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4
# 5       25.29  4.71    Male     No  Sun  Dinner     4
# 6        8.77  2.00    Male     No  Sun  Dinner     2
# 7       26.88  3.12    Male     No  Sun  Dinner     4
# 8       15.04  1.96    Male     No  Sun  Dinner     2
# 9       14.78  3.23    Male     No  Sun  Dinner     2

# %%
df['total_bill']
# Out:
# 0      16.99
# 1      10.34
# 2      21.01
# 3      23.68
# 4      24.59
# 5      25.29
# 6       8.77
# 7      26.88
# 8      15.04
# 9      14.78
# 10     10.27
# 11     35.26
# 12     15.42
# 13     18.43
# 14     14.83
# 15     21.58
# 16     10.33
# 17     16.29
# 18     16.97
# 19     20.65
# 20     17.92
# 21     20.29
# 22     15.77
# 23     39.42
# 24     19.82
# 25     17.81
# 26     13.37
# 27     12.69
# 28     21.70
# 29     19.65
#        ...
# 214    28.17
# 215    12.90
# 216    28.15
# 217    11.59
# 218     7.74
# 219    30.14
# 220    12.16
# 221    13.42
# 222     8.58
# 223    15.98
# 224    13.42
# 225    16.27
# 226    10.09
# 227    20.45
# 228    13.28
# 229    22.12
# 230    24.01
# 231    15.69
# 232    11.61
# 233    10.77
# 234    15.53
# 235    10.07
# 236    12.60
# 237    32.83
# 238    35.83
# 239    29.03
# 240    27.18
# 241    22.67
# 242    17.82
# 243    18.78
# Name: total_bill, Length: 244, dtype: float64

# %%
sns.distplot(df['total_bill'],kde=False,rug=True)

# %%
df=sns.load_dataset('iris')

# %%
df.head(10)
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa
# 5           5.4          3.9           1.7          0.4  setosa
# 6           4.6          3.4           1.4          0.3  setosa
# 7           5.0          3.4           1.5          0.2  setosa
# 8           4.4          2.9           1.4          0.2  setosa
# 9           4.9          3.1           1.5          0.1  setosa

# %%
sns.distplot(df['sepal_length'])

# %%
x=[1,2,3,4,5,6,7]
sns.kdeplot(x)

# %%
x=[1,2,3,4,5,6,7]
sns.kdeplot(x,shade=True,color='k')

# %%
x=[1,2,3,4,5,6,7]
y=[2,3,7,8,9,6,4]
sns.kdeplot(x,y,color='r',bw=0.5)

# %%
sns.palplot(sns.color_palette())

# %%
sns.palplot(sns.color_palette('RdBu',n_colors=15))

# %%
sns.palplot(sns.color_palette('RdBu',15))

# %%
x=sns.color_palette('BrBG',10)
sns.palplot(x)

# %%
x=sns.cubehelix_palette()

# %%
sns.palplot(x)

# %%
x=sns.cubehelix_palette(reverse=True)
sns.palplot(x)

# %%
x=sns.cubehelix_palette(rot=-0.1)
sns.palplot(x)

# %%
x=sns.cubehelix_palette(start=2.1,rot=2.1,reverse=True)
sns.palplot(x)

# %%
from numpy import arange

# %%
from numpy import arange
x=arange(16).reshape(4,4)

d=sns.cubehelix_palette(rot=-0.1)
ax=sns.heatmap(d)

# %%
import pandas as pd

# %%
sns.set(style='white')
tips=sns.load_dataset('tips')
tips.head()
sns.jointplot(x='total_bill',y='tip',data=tips,kind='reg')

# %%
sns.jointplot(x='total_bill',y='tip',data=tips,kind='hex',color='r')

# %%
iris=sns.load_dataset('iris')
iris.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
iris['species'].unique()
# Out:
# array(['setosa', 'versicolor', 'virginica'], dtype=object)

# %%
sns.pairplot(iris,hue='species')

# %%
sns.pairplot(iris)

# %%
sns.stripplot(data=iris,x='species',y='sepal_length')

# %%
sns.swarmplot(data=iris,x='species',y='sepal_length')

# %%
sns.pointplot(data=iris,x='species',y='sepal_length')

# %%
sns.violinplot(data=iris,x='species',y='sepal_length')

# %%
sns.pointplot(data=tips,x='time',y='total_bill',hue='sex')

# %%
sns.boxplot(data=tips,x='time',y='total_bill',hue='sex')

# %%
sns.barplot(data=tips,x='time',y='total_bill',hue='sex')
