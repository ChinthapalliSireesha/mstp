# %% [markdown]
# ### CREATING SERIES IN PANDAS

# %%
import pandas as pd

# %%
animals=['tiger','bear','moose']
s=pd.Series(animals)

# %%
s
# Out:
# 0    tiger
# 1     bear
# 2    moose
# dtype: object

# %%
s.index
# Out:
# RangeIndex(start=0, stop=3, step=1)

# %%
s.name='Animals'

# %%
s.name
# Out:
# 'Animals'

# %%
s
# Out:
# 0    tiger
# 1     bear
# 2    moose
# Name: Animals, dtype: object

# %%
numbers=[1,2,3]
pd.Series(numbers)
# Out:
# 0    1
# 1    2
# 2    3
# dtype: int64

# %%
animals=['tiger','bear',None]
s=pd.Series(animals)

# %%
s
# Out:
# 0    tiger
# 1     bear
# 2     None
# dtype: object

# %%
numbers=[1,2,None]
pd.Series(numbers)##NaN------->Not a Number
# Out:
# 0    1.0
# 1    2.0
# 2    NaN
# dtype: float64

# %%
a=2
b=2
a==b
# Out:
# True

# %% [markdown]
# ## NUMPY

# %%
import numpy as np

# %%
np.NaN== None
# Out:
# False

# %%
np.nan==np.nan
# Out:
# False

# %%
np.nan is np.nan
# Out:
# True

# %%
np.isnan(np.nan)scotland
# Out:
# True

# %%
sports={'Archery':'Bhutan','Golf':'scotland','sumo':'Japan','Taekwondo':'South korea'}

# %%
s=pd.Series(sports)

# %%
s
# Out:
# Archery           Bhutan
# Golf            scotland
# sumo               Japan
# Taekwondo    South korea
# dtype: object

# %%
s.index
# Out:
# Index(['Archery', 'Golf', 'sumo', 'Taekwondo'], dtype='object')

# %%
s=pd.Series(['Tiger','Bear','Moose'],index=['India','America','canada'])
s
# Out:
# India      Tiger
# America     Bear
# canada     Moose
# dtype: object

# %%
sports={'Archery':'Bhutan','Golf':'scotland','sumo':'Japan','Taekwondo':'South korea'}
s=pd.Series(sports,index=['Golf','sumo','Hockey','Bhutan'])

# %%
s
# Out:
# Golf      scotland
# sumo         Japan
# Hockey         NaN
# Bhutan         NaN
# dtype: object

# %%
s=pd.Series(sports)

# %%
s
# Out:
# Archery           Bhutan
# Golf            scotland
# sumo               Japan
# Taekwondo    South korea
# dtype: object

# %%
s.iloc[3]
# Out:
# 'South korea'

# %%
s[3]
# Out:
# 'South korea'

# %%
s.loc['sumo']
# Out:
# 'Japan'

# %%
sports={99:'Bhutan',100:'scotland',101:'Japan',102:'South korea'}

# %%
s=pd.Series(sports)

# %%
s
# Out:
# 99          Bhutan
# 100       scotland
# 101          Japan
# 102    South korea
# dtype: object

# %%
s.iloc[3]
# Out:
# 'South korea'

# %%
s.loc[99]
# Out:
# 'Bhutan'

# %%
for each in s:
    print(each)
# Out:
# Bhutan
# scotland
# Japan
# South korea

# %%
s=pd.Series([100.00,200.00,300.00])

# %% [markdown]
# ### Sum of given numbers using SUM() in numpy:

# %%
import numpy as np

# %%
total=sum(s)
print(total)
# Out:
# 600.0

# %%
np.random.randint(0,1000,10000)
# Out:
# array([478, 851, 218, ..., 519, 839, 611])

# %%
s=pd.Series(np.random.randint(0,1000,10000))
s.head()
# Out:
# 0    133
# 1    877
# 2    154
# 3    282
# 4    546
# dtype: int32

# %%
# %%timeit -n 100

summary=0
for item in s:
    summary+=item## Magical function in jupiter notebook
# Out:
# 1.37 ms ± 97.8 µs per loop (mean ± std. dev. of 7 runs, 100 loops each)

# %%
# %%timeit -n 5
summary=np.sum(s)
# Out:
# The slowest run took 4.13 times longer than the fastest. This could mean that an intermediate result is being cached.
# 254 µs ± 149 µs per loop (mean ± std. dev. of 7 runs, 5 loops each)

# %%
s.head()
# Out:
# 0    133
# 1    877
# 2    154
# 3    282
# 4    546
# dtype: int32

# %%
s+=2

# %%
s.head()##adds two to each item in s using broadcasting
# Out:
# 0    135
# 1    879
# 2    156
# 3    284
# 4    548
# dtype: int32

# %%
for label,value in s.iteritems():
    s.set_value(label,value+2)
s.head()
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:2: FutureWarning: set_value is deprecated and will be removed in a future release. Please use .at[] or .iat[] accessors instead
# 0    139
# 1    883
# 2    160
# 3    288
# 4    552
# dtype: int32

# %%
s.set_value(0,300)
s.head()
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: FutureWarning: set_value is deprecated and will be removed in a future release. Please use .at[] or .iat[] accessors instead
#   """Entry point for launching an IPython kernel.
# 0    300
# 1    883
# 2    160
# 3    288
# 4    552
# dtype: int32

# %%
# %%timeit -n 1
s=pd.Series(np.random.randint(0,1000,10000))
s+=2
# Out:
# 773 µs ± 144 µs per loop (mean ± std. dev. of 7 runs, 1 loop each)

# %%
# %%timeit -n 1
s=pd.Series(np.random.randint(0,1000,10000))
for label,value in s.iteritems():
    s.loc[label]=value+2
# Out:
# 4.43 s ± 272 ms per loop (mean ± std. dev. of 7 runs, 1 loop each)

# %% [markdown]
# ## 18 sep 2019

# %%
import pandas as pd
original_sports =pd.Series({'Archery':'Bhutan','Golf':'Scotland','Sumo':'Japan','taekwondo':'South Korea'})
cricket_loving_countries=pd.Series(['Australia','Borbados','pakistan','england'],index=['cricket','cricket','cricket','cricket'])
all_countries=original_sports.append(cricket_loving_countries)

# %%
original_sports
# Out:
# Archery           Bhutan
# Golf            Scotland
# Sumo               Japan
# taekwondo    South Korea
# dtype: object

# %%
cricket_loving_countries
# Out:
# cricket    Australia
# cricket     Borbados
# cricket     pakistan
# cricket      england
# dtype: object

# %%
all_countries
# Out:
# Archery           Bhutan
# Golf            Scotland
# Sumo               Japan
# taekwondo    South Korea
# cricket        Australia
# cricket         Borbados
# cricket         pakistan
# cricket          england
# dtype: object

# %%
all_countries.loc['cricket']
# Out:
# cricket    Australia
# cricket     Borbados
# cricket     pakistan
# cricket      england
# dtype: object

# %%
all_countries.iloc[0]
# Out:
# 'Bhutan'

# %% [markdown]
# ### UPDATE

# %%
all_countries[4]='australia'

# %%
all_countries
# Out:
# Archery           Bhutan
# Golf            Scotland
# Sumo               Japan
# taekwondo    South Korea
# cricket        australia
# cricket         Borbados
# cricket         pakistan
# cricket          england
# dtype: object

# %% [markdown]
# ### The Data Frame Data Structure

# %%
purchase_1=pd.Series({'Name':'Chris','Item Purchased':'Dog Food','Cost':22.50})
purchase_2=pd.Series({'Name':'Kevyn','Item Purchased':'kitty litter','Cost':2.50})
purchase_3=pd.Series({'Name':'Vinod','Item Purchased':'Bird seed','Cost':5.00})
df=pd.DataFrame([purchase_1,purchase_2,purchase_3],index=['store1','store1','store2'])
df.head()
# Out:
#          Name Item Purchased  Cost
# store1  Chris       Dog Food  22.5
# store1  Kevyn   kitty litter   2.5
# store2  Vinod      Bird seed   5.0

# %%
df.loc['store2']
# Out:
# Name                  Vinod
# Item Purchased    Bird seed
# Cost                      5
# Name: store2, dtype: object

# %%
df.loc['store1']
# Out:
#          Name Item Purchased  Cost
# store1  Chris       Dog Food  22.5
# store1  Kevyn   kitty litter   2.5

# %%
df.loc['store1','Name']
# Out:
# store1    Chris
# store1    Kevyn
# Name: Name, dtype: object

# %%
df
# Out:
#          Name Item Purchased  Cost
# store1  Chris       Dog Food  22.5
# store1  Kevyn   kitty litter   2.5
# store2  Vinod      Bird seed   5.0

# %%
df.T
# Out:
#                   store1        store1     store2
# Name               Chris         Kevyn      Vinod
# Item Purchased  Dog Food  kitty litter  Bird seed
# Cost                22.5           2.5          5

# %%
df
# Out:
#          Name Item Purchased  Cost
# store1  Chris       Dog Food  22.5
# store1  Kevyn   kitty litter   2.5
# store2  Vinod      Bird seed   5.0

# %%
df.T.loc['Item Purchased']
# Out:
# store1        Dog Food
# store1    kitty litter
# store2       Bird seed
# Name: Item Purchased, dtype: object

# %%
df['Cost']
# Out:
# store1    22.5
# store1     2.5
# store2     5.0
# Name: Cost, dtype: float64

# %%
df.loc[:,['Name','Cost']]
# Out:
#          Name  Cost
# store1  Chris  22.5
# store1  Kevyn   2.5
# store2  Vinod   5.0

# %%
copy_df=df.copy()
copy_df=copy_df.drop('store1')
copy_df
# Out:
#          Name Item Purchased  Cost
# store2  Vinod      Bird seed   5.0

# %%
copy_df=df.copy()
copy_df=copy_df.drop('store1')
copy_df
# Out:
#          Name Item Purchased  Cost
# store2  Vinod      Bird seed   5.0

# %%
copy_df
# Out:
#          Name Item Purchased  Cost
# store2  Vinod      Bird seed   5.0

# %%
del copy_df['Name']
copy_df
# Out:
#        Item Purchased  Cost
# store2      Bird seed   5.0

# %%
df['Location']=None
df
# Out:
#          Name Item Purchased  Cost Location
# store1  Chris       Dog Food  22.5     None
# store1  Kevyn   kitty litter   2.5     None
# store2  Vinod      Bird seed   5.0     None

# %%
df['state']=['ap','tg','delhi']
df
# Out:
#          Name Item Purchased  Cost Location  state
# store1  Chris       Dog Food  22.5     None     ap
# store1  Kevyn   kitty litter   2.5     None     tg
# store2  Vinod      Bird seed   5.0     None  delhi

# %%
df.loc['store2','state']='mumbai'

# %%
df
# Out:
#          Name Item Purchased  Cost Location   state
# store1  Chris       Dog Food  22.5     None      ap
# store1  Kevyn   kitty litter   2.5     None      tg
# store2  Vinod      Bird seed   5.0     None  mumbai

# %%
df['state']['store2']='Mumbai'
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
df
# Out:
#          Name Item Purchased  Cost Location   state
# store1  Chris       Dog Food  22.5     None      ap
# store1  Kevyn   kitty litter   2.5     None      tg
# store2  Vinod      Bird seed   5.0     None  Mumbai

# %%
costs=df['Cost']

# %%
costs
# Out:
# store1    22.5
# store1     2.5
# store2     5.0
# Name: Cost, dtype: float64

# %%
costs+=2
costs
# Out:
# store1    24.5
# store1     4.5
# store2     7.0
# Name: Cost, dtype: float64

# %%
df=pd.read_csv('olympics.csv')
df.head()
# Out:
#                    0         1     2     3     4      5         6     7     8  \
# 0                NaN  № Summer  01 !  02 !  03 !  Total  № Winter  01 !  02 !
# 1  Afghanistan (AFG)        13     0     0     2      2         0     0     0
# 2      Algeria (ALG)        12     5     2     8     15         3     0     0
# 3    Argentina (ARG)        23    18    24    28     70        18     0     0
# 4      Armenia (ARM)         5     1     2     9     12         6     0     0
#
#       9     10       11    12    13    14              15
# 0  03 !  Total  № Games  01 !  02 !  03 !  Combined total
# 1     0      0       13     0     0     2               2
# 2     0      0       15     5     2     8              15
# 3     0      0       41    18    24    28              70
# 4     0      0       11     1     2     9              12

# %%
df=pd.read_csv('olympics.csv',index_col=0,skiprows=1)
df.head()
# Out:
#                          № Summer  01 !  02 !  03 !  Total  № Winter  01 !.1  \
# Afghanistan (AFG)              13     0     0     2      2         0       0
# Algeria (ALG)                  12     5     2     8     15         3       0
# Argentina (ARG)                23    18    24    28     70        18       0
# Armenia (ARM)                   5     1     2     9     12         6       0
# Australasia (ANZ) [ANZ]         2     3     4     5     12         0       0
#
#                          02 !.1  03 !.1  Total.1  № Games  01 !.2  02 !.2  \
# Afghanistan (AFG)             0       0        0       13       0       0
# Algeria (ALG)                 0       0        0       15       5       2
# Argentina (ARG)               0       0        0       41      18      24
# Armenia (ARM)                 0       0        0       11       1       2
# Australasia (ANZ) [ANZ]       0       0        0        2       3       4
#
#                          03 !.2  Combined total
# ...

# %%
for col in df.columns:
    if col[:2]=='01':
        df.rename(columns={col:'Gold'+col[4:]},inplace=True)
    if col[:2]=='02':
        df.rename(columns={col:'Silver'+col[4:]},inplace=True)
    if col[:2]=='03':
        df.rename(columns={col:'Bronze'+col[4:]},inplace=True)
    if col[:1]=='№':
        df.rename(columns={col:'#'+col[1:]},inplace=True)
df.head()
# Out:
#                          # Summer  Gold  Silver  Bronze  Total  # Winter  \
# Afghanistan (AFG)              13     0       0       2      2         0
# Algeria (ALG)                  12     5       2       8     15         3
# Argentina (ARG)                23    18      24      28     70        18
# Armenia (ARM)                   5     1       2       9     12         6
# Australasia (ANZ) [ANZ]         2     3       4       5     12         0
#
#                          Gold.1  Silver.1  Bronze.1  Total.1  # Games  Gold.2  \
# Afghanistan (AFG)             0         0         0        0       13       0
# Algeria (ALG)                 0         0         0        0       15       5
# Argentina (ARG)               0         0         0        0       41      18
# Armenia (ARM)                 0         0         0        0       11       1
# Australasia (ANZ) [ANZ]       0         0         0        0        2       3
#
# ...

# %% [markdown]
# ### 1)Find the countries names who got more or equal to 1 gold medal in summer

# %%
a=df.where(df['Gold']>=1)
a.head()
# Out:
#                          # Summer  Gold  Silver  Bronze  Total  # Winter  \
# Afghanistan (AFG)             NaN   NaN     NaN     NaN    NaN       NaN
# Algeria (ALG)                12.0   5.0     2.0     8.0   15.0       3.0
# Argentina (ARG)              23.0  18.0    24.0    28.0   70.0      18.0
# Armenia (ARM)                 5.0   1.0     2.0     9.0   12.0       6.0
# Australasia (ANZ) [ANZ]       2.0   3.0     4.0     5.0   12.0       0.0
#
#                          Gold.1  Silver.1  Bronze.1  Total.1  # Games  Gold.2  \
# Afghanistan (AFG)           NaN       NaN       NaN      NaN      NaN     NaN
# Algeria (ALG)               0.0       0.0       0.0      0.0     15.0     5.0
# Argentina (ARG)             0.0       0.0       0.0      0.0     41.0    18.0
# Armenia (ARM)               0.0       0.0       0.0      0.0     11.0     1.0
# Australasia (ANZ) [ANZ]     0.0       0.0       0.0      0.0      2.0     3.0
#
# ...

# %%
a['Gold'].count()
# Out:
# 100

# %% [markdown]
# ### dropna() {to delete NAN rows)

# %%
a=a.dropna()
a.head()
# Out:
#                            # Summer   Gold  Silver  Bronze  Total  # Winter  \
# Algeria (ALG)                  12.0    5.0     2.0     8.0   15.0       3.0
# Argentina (ARG)                23.0   18.0    24.0    28.0   70.0      18.0
# Armenia (ARM)                   5.0    1.0     2.0     9.0   12.0       6.0
# Australasia (ANZ) [ANZ]         2.0    3.0     4.0     5.0   12.0       0.0
# Australia (AUS) [AUS] [Z]      25.0  139.0   152.0   177.0  468.0      18.0
#
#                            Gold.1  Silver.1  Bronze.1  Total.1  # Games  \
# Algeria (ALG)                 0.0       0.0       0.0      0.0     15.0
# Argentina (ARG)               0.0       0.0       0.0      0.0     41.0
# Armenia (ARM)                 0.0       0.0       0.0      0.0     11.0
# Australasia (ANZ) [ANZ]       0.0       0.0       0.0      0.0      2.0
# Australia (AUS) [AUS] [Z]     5.0       3.0       4.0     12.0     43.0
#
#                            Gold.2  Silver.2  Bronze.2  Combined total
# ...

# %%
a=df[df['Gold']>=1]
a.head()
# Out:
#                            # Summer  Gold  Silver  Bronze  Total  # Winter  \
# Algeria (ALG)                    12     5       2       8     15         3
# Argentina (ARG)                  23    18      24      28     70        18
# Armenia (ARM)                     5     1       2       9     12         6
# Australasia (ANZ) [ANZ]           2     3       4       5     12         0
# Australia (AUS) [AUS] [Z]        25   139     152     177    468        18
#
#                            Gold.1  Silver.1  Bronze.1  Total.1  # Games  \
# Algeria (ALG)                   0         0         0        0       15
# Argentina (ARG)                 0         0         0        0       41
# Armenia (ARM)                   0         0         0        0       11
# Australasia (ANZ) [ANZ]         0         0         0        0        2
# Australia (AUS) [AUS] [Z]       5         3         4       12       43
#
#                            Gold.2  Silver.2  Bronze.2  Combined total
# ...

# %% [markdown]
# ### find the count of countries who got atleast 1 silver medals in either summer or winter?

# %%
b=df.where(df['Silver']>=1)
b.head()
# Out:
#                          # Summer  Gold  Silver  Bronze  Total  # Winter  \
# Afghanistan (AFG)             NaN   NaN     NaN     NaN    NaN       NaN
# Algeria (ALG)                12.0   5.0     2.0     8.0   15.0       3.0
# Argentina (ARG)              23.0  18.0    24.0    28.0   70.0      18.0
# Armenia (ARM)                 5.0   1.0     2.0     9.0   12.0       6.0
# Australasia (ANZ) [ANZ]       2.0   3.0     4.0     5.0   12.0       0.0
#
#                          Gold.1  Silver.1  Bronze.1  Total.1  # Games  Gold.2  \
# Afghanistan (AFG)           NaN       NaN       NaN      NaN      NaN     NaN
# Algeria (ALG)               0.0       0.0       0.0      0.0     15.0     5.0
# Argentina (ARG)             0.0       0.0       0.0      0.0     41.0    18.0
# Armenia (ARM)               0.0       0.0       0.0      0.0     11.0     1.0
# Australasia (ANZ) [ANZ]     0.0       0.0       0.0      0.0      2.0     3.0
#
# ...

# %%
b['Silver'].count()
# Out:
# 125

# %%
c=df.where(df['Bronze']>=1)
c.head()
# Out:
#                          # Summer  Gold  Silver  Bronze  Total  # Winter  \
# Afghanistan (AFG)            13.0   0.0     0.0     2.0    2.0       0.0
# Algeria (ALG)                12.0   5.0     2.0     8.0   15.0       3.0
# Argentina (ARG)              23.0  18.0    24.0    28.0   70.0      18.0
# Armenia (ARM)                 5.0   1.0     2.0     9.0   12.0       6.0
# Australasia (ANZ) [ANZ]       2.0   3.0     4.0     5.0   12.0       0.0
#
#                          Gold.1  Silver.1  Bronze.1  Total.1  # Games  Gold.2  \
# Afghanistan (AFG)           0.0       0.0       0.0      0.0     13.0     0.0
# Algeria (ALG)               0.0       0.0       0.0      0.0     15.0     5.0
# Argentina (ARG)             0.0       0.0       0.0      0.0     41.0    18.0
# Armenia (ARM)               0.0       0.0       0.0      0.0     11.0     1.0
# Australasia (ANZ) [ANZ]     0.0       0.0       0.0      0.0      2.0     3.0
#
# ...

# %%
c['Silver'].count()
# Out:
# 124

# %%
a=df[df['Silver.2']>=1]
a.head()
# Out:
#                            # Summer  Gold  Silver  Bronze  Total  # Winter  \
# Algeria (ALG)                    12     5       2       8     15         3
# Argentina (ARG)                  23    18      24      28     70        18
# Armenia (ARM)                     5     1       2       9     12         6
# Australasia (ANZ) [ANZ]           2     3       4       5     12         0
# Australia (AUS) [AUS] [Z]        25   139     152     177    468        18
#
#                            Gold.1  Silver.1  Bronze.1  Total.1  # Games  \
# Algeria (ALG)                   0         0         0        0       15
# Argentina (ARG)                 0         0         0        0       41
# Armenia (ARM)                   0         0         0        0       11
# Australasia (ANZ) [ANZ]         0         0         0        0        2
# Australia (AUS) [AUS] [Z]       5         3         4       12       43
#
#                            Gold.2  Silver.2  Bronze.2  Combined total
# ...

# %%
a['Silver.2'].count()
# Out:
# 126

# %%
len(df[(df['Gold']>0) | (df['Gold.1']>0)])
# Out:
# 101

# %% [markdown]
# ### find the countries which got atleast 1 gold metal in winter and not got gold medal in summer

# %%
df[(df['Gold.1']>0) & (df['Gold']==0)]
# Out:
#                      # Summer  Gold  Silver  Bronze  Total  # Winter  Gold.1  \
# Liechtenstein (LIE)        16     0       0       0      0        18       2
#
#                      Silver.1  Bronze.1  Total.1  # Games  Gold.2  Silver.2  \
# Liechtenstein (LIE)         2         5        9       34       2         2
#
#                      Bronze.2  Combined total
# Liechtenstein (LIE)         5               9

# %% [markdown]
# ### to change the index column using set_index()

# %%
df['country']=df.index
df.set_index('Gold').head()
# Out:
#                          # Summer  Silver  Bronze  Total  # Winter  Gold.1  \
# Gold
# Afghanistan (AFG)              13       0       2      2         0       0
# Algeria (ALG)                  12       2       8     15         3       0
# Argentina (ARG)                23      24      28     70        18       0
# Armenia (ARM)                   5       2       9     12         6       0
# Australasia (ANZ) [ANZ]         2       4       5     12         0       0
#
#                          Silver.1  Bronze.1  Total.1  # Games  Gold.2  \
# Gold
# Afghanistan (AFG)               0         0        0       13       0
# Algeria (ALG)                   0         0        0       15       5
# Argentina (ARG)                 0         0        0       41      18
# Armenia (ARM)                   0         0        0       11       1
# Australasia (ANZ) [ANZ]         0         0        0        2       3
#
#                          Silver.2  Bronze.2  Combined total  \
# Gold
# ...

# %%
df['Gold']=df.index
df.set_index('country').head()
# Out:
#                          # Summer                     Gold  Silver  Bronze  \
# country
# Afghanistan (AFG)              13        Afghanistan (AFG)       0       2
# Algeria (ALG)                  12            Algeria (ALG)       2       8
# Argentina (ARG)                23          Argentina (ARG)      24      28
# Armenia (ARM)                   5            Armenia (ARM)       2       9
# Australasia (ANZ) [ANZ]         2  Australasia (ANZ) [ANZ]       4       5
#
#                          Total  # Winter  Gold.1  Silver.1  Bronze.1  Total.1  \
# country
# Afghanistan (AFG)            2         0       0         0         0        0
# Algeria (ALG)               15         3       0         0         0        0
# Argentina (ARG)             70        18       0         0         0        0
# Armenia (ARM)               12         6       0         0         0        0
# Australasia (ANZ) [ANZ]     12         0       0         0         0        0
#
# ...

# %% [markdown]
# ### to change the index using reset.index()

# %%
df=df.reset_index()
df.head()
# Out:
#    level_0                    index  # Summer                     Gold  \
# 0        0        Afghanistan (AFG)        13        Afghanistan (AFG)
# 1        1            Algeria (ALG)        12            Algeria (ALG)
# 2        2          Argentina (ARG)        23          Argentina (ARG)
# 3        3            Armenia (ARM)         5            Armenia (ARM)
# 4        4  Australasia (ANZ) [ANZ]         2  Australasia (ANZ) [ANZ]
#
#    Silver  Bronze  Total  # Winter  Gold.1  Silver.1  Bronze.1  Total.1  \
# 0       0       2      2         0       0         0         0        0
# 1       2       8     15         3       0         0         0        0
# 2      24      28     70        18       0         0         0        0
# 3       2       9     12         6       0         0         0        0
# 4       4       5     12         0       0         0         0        0
#
#    # Games  Gold.2  Silver.2  Bronze.2  Combined total  \
# ...

# %%
a=df['Afghanistan']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2656             try:
# -> 2657                 return self._engine.get_loc(key)
#    2658             except KeyError:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Afghanistan'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-120-b21bb6df1a42> in <module>
# ----> 1 a=df['Afghanistan']
#
# ...

# %%
high=0
for i in df['Gold']:
    if i>high:
        i=high
print(high)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-122-258fe2b14bc3> in <module>
#       1 high=0
#       2 for i in df['Gold']:
# ----> 3     if i>high:
#       4         i=high
#       5 print(high)
#
# TypeError: '>' not supported between instances of 'str' and 'int'

# %%
df=pd.read_csv('census.csv')
df.head()
# Out:
#    SUMLEV  REGION  DIVISION  STATE  COUNTY   STNAME         CTYNAME  \
# 0      40       3         6      1       0  Alabama         Alabama
# 1      50       3         6      1       1  Alabama  Autauga County
# 2      50       3         6      1       3  Alabama  Baldwin County
# 3      50       3         6      1       5  Alabama  Barbour County
# 4      50       3         6      1       7  Alabama     Bibb County
#
#    CENSUS2010POP  ESTIMATESBASE2010  POPESTIMATE2010  ...  RDOMESTICMIG2011  \
# 0        4779736            4780127          4785161  ...          0.002295
# 1          54571              54571            54660  ...          7.242091
# 2         182265             182265           183193  ...         14.832960
# 3          27457              27457            27341  ...         -4.728132
# 4          22915              22919            22861  ...         -5.527043
#
#    RDOMESTICMIG2012  RDOMESTICMIG2013  RDOMESTICMIG2014  RDOMESTICMIG2015  \
# ...

# %%
df=df[df['SUMLEV']==50]
df.head()
# Out:
#    SUMLEV  REGION  DIVISION  STATE  COUNTY   STNAME         CTYNAME  \
# 1      50       3         6      1       1  Alabama  Autauga County
# 2      50       3         6      1       3  Alabama  Baldwin County
# 3      50       3         6      1       5  Alabama  Barbour County
# 4      50       3         6      1       7  Alabama     Bibb County
# 5      50       3         6      1       9  Alabama   Blount County
#
#    CENSUS2010POP  ESTIMATESBASE2010  POPESTIMATE2010  ...  RDOMESTICMIG2011  \
# 1          54571              54571            54660  ...          7.242091
# 2         182265             182265           183193  ...         14.832960
# 3          27457              27457            27341  ...         -4.728132
# 4          22915              22919            22861  ...         -5.527043
# 5          57322              57322            57373  ...          1.807375
#
#    RDOMESTICMIG2012  RDOMESTICMIG2013  RDOMESTICMIG2014  RDOMESTICMIG2015  \
# ...

# %%
df[['SUMLEV','STATE','COUNTY']]
# Out:
#       SUMLEV  STATE  COUNTY
# 1         50      1       1
# 2         50      1       3
# 3         50      1       5
# 4         50      1       7
# 5         50      1       9
# 6         50      1      11
# 7         50      1      13
# 8         50      1      15
# 9         50      1      17
# 10        50      1      19
# 11        50      1      21
# 12        50      1      23
# 13        50      1      25
# 14        50      1      27
# 15        50      1      29
# 16        50      1      31
# 17        50      1      33
# 18        50      1      35
# 19        50      1      37
# 20        50      1      39
# 21        50      1      41
# 22        50      1      43
# 23        50      1      45
# 24        50      1      47
# 25        50      1      49
# 26        50      1      51
# 27        50      1      53
# 28        50      1      55
# 29        50      1      57
# 30        50      1      59
# ...      ...    ...     ...
# 3162      50     55     129
# ...

# %%
df=df.set_index(['STNAME','CTYNAME'])
df.head()
# Out:
#                         SUMLEV  REGION  DIVISION  STATE  COUNTY  \
# STNAME  CTYNAME
# Alabama Autauga County      50       3         6      1       1
#         Baldwin County      50       3         6      1       3
#         Barbour County      50       3         6      1       5
#         Bibb County         50       3         6      1       7
#         Blount County       50       3         6      1       9
#
#                         CENSUS2010POP  ESTIMATESBASE2010  POPESTIMATE2010  \
# STNAME  CTYNAME
# Alabama Autauga County          54571              54571            54660
#         Baldwin County         182265             182265           183193
#         Barbour County          27457              27457            27341
#         Bibb County             22915              22919            22861
#         Blount County           57322              57322            57373
#
#                         POPESTIMATE2011  POPESTIMATE2012  ...  \
# ...

# %%
N = int(input())
a=input().split()
for i in N:
    print(data)
# Out:
# 5
# 1
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-140-5a1fd8f27a87> in <module>
#       1 N = int(input())
#       2 a=input().split()
# ----> 3 for i in N:
#       4     print(data)
#
# TypeError: 'int' object is not iterable

# %%
df.loc['Alabama','Autauga County']
# Out:
# SUMLEV                      50.000000
# REGION                       3.000000
# DIVISION                     6.000000
# STATE                        1.000000
# COUNTY                       1.000000
# CENSUS2010POP            54571.000000
# ESTIMATESBASE2010        54571.000000
# POPESTIMATE2010          54660.000000
# POPESTIMATE2011          55253.000000
# POPESTIMATE2012          55175.000000
# POPESTIMATE2013          55038.000000
# POPESTIMATE2014          55290.000000
# POPESTIMATE2015          55347.000000
# NPOPCHG_2010                89.000000
# NPOPCHG_2011               593.000000
# NPOPCHG_2012               -78.000000
# NPOPCHG_2013              -137.000000
# NPOPCHG_2014               252.000000
# NPOPCHG_2015                57.000000
# BIRTHS2010                 151.000000
# BIRTHS2011                 636.000000
# BIRTHS2012                 615.000000
# BIRTHS2013                 574.000000
# BIRTHS2014                 623.000000
# BIRTHS2015                 600.000000
# ...

# %%
df.loc[[('Michigan', 'Wastenaw County'),('Michigan', 'Wayne County')]]
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: FutureWarning:
# Passing list-likes to .loc or [] with any missing label will raise
# KeyError in the future, you can use .reindex() as an alternative.
#
# See the documentation here:
# https://pandas.pydata.org/pandas-docs/stable/indexing.html#deprecate-loc-reindex-listlike
#   """Entry point for launching an IPython kernel.
#                           SUMLEV  REGION  DIVISION  STATE  COUNTY  \
# STNAME   CTYNAME
# Michigan Wastenaw County     NaN     NaN       NaN    NaN     NaN
#          Wayne County       50.0     2.0       3.0   26.0   163.0
#
#                           CENSUS2010POP  ESTIMATESBASE2010  POPESTIMATE2010  \
# STNAME   CTYNAME
# Michigan Wastenaw County            NaN                NaN              NaN
#          Wayne County         1820584.0          1820641.0        1815199.0
#
#                           POPESTIMATE2011  POPESTIMATE2012  ...  \
# ...

# %% [markdown]
# ### Missing Values:

# %%
df=pd.read_csv('log.csv')
df
# Out:
#           time    user          video  playback position paused  volume
# 0   1469974424  cheryl     intro.html                  5  False    10.0
# 1   1469974454  cheryl     intro.html                  6    NaN     NaN
# 2   1469974544  cheryl     intro.html                  9    NaN     NaN
# 3   1469974574  cheryl     intro.html                 10    NaN     NaN
# 4   1469977514     bob     intro.html                  1    NaN     NaN
# 5   1469977544     bob     intro.html                  1    NaN     NaN
# 6   1469977574     bob     intro.html                  1    NaN     NaN
# 7   1469977604     bob     intro.html                  1    NaN     NaN
# 8   1469974604  cheryl     intro.html                 11    NaN     NaN
# 9   1469974694  cheryl     intro.html                 14    NaN     NaN
# 10  1469974724  cheryl     intro.html                 15    NaN     NaN
# 11  1469974454     sue  advanced.html                 24    NaN     NaN
# ...

# %%
df=df.set_index('time')
df=df.sort_index()
df.head()
# Out:
#               user          video  playback position paused  volume
# time
# 1469974424  cheryl     intro.html                  5  False    10.0
# 1469974424     sue  advanced.html                 23  False    10.0
# 1469974454  cheryl     intro.html                  6    NaN     NaN
# 1469974454     sue  advanced.html                 24    NaN     NaN
# 1469974484  cheryl     intro.html                  7    NaN     NaN

# %%
df=df.reset_index()
df=df.set_index(['time','user'])
df.head()
# Out:
#                            video  playback position paused volume
# time       user
# 1469974424 cheryl     intro.html                  5  False     10
#            sue     advanced.html                 23  False     10
# 1469974454 cheryl     intro.html                  6   siri   siri
#            sue     advanced.html                 24   siri   siri
# 1469974484 cheryl     intro.html                  7   siri   siri

# %% [markdown]
# ## Fillna()

# %%
df=df.fillna('siri')

# %%
df.head()
# Out:
#                            video  playback position paused volume
# time       user
# 1469974424 cheryl     intro.html                  5  False     10
#            sue     advanced.html                 23  False     10
# 1469974454 cheryl     intro.html                  6   siri   siri
#            sue     advanced.html                 24   siri   siri
# 1469974484 cheryl     intro.html                  7   siri   siri

# %% [markdown]
# ### ffill and bfill

# %%
df.fillna(method='ffill').head()
# Out:
#               user          video  playback position  paused  volume
# time
# 1469974424  cheryl     intro.html                  5   False    10.0
# 1469974424     sue  advanced.html                 23   False    10.0
# 1469974454  cheryl     intro.html                  6   False    10.0
# 1469974454     sue  advanced.html                 24   False    10.0
# 1469974484  cheryl     intro.html                  7   False    10.0

# %%
df.fillna(method='bfill').head()
# Out:
#               user          video  playback position paused  volume
# time
# 1469974424  cheryl     intro.html                  5  False    10.0
# 1469974424     sue  advanced.html                 23  False    10.0
# 1469974454  cheryl     intro.html                  6   True     5.0
# 1469974454     sue  advanced.html                 24   True     5.0
# 1469974484  cheryl     intro.html                  7   True     5.0
