# %%
import pandas as pd
dict={'name':['siri','deepu','keeru','hari'],'rno':['522','530','511','541'],'age':[21,22,23,24],'place':['Narspur','tatipaka','manepalli','Narspur']}

# %%
df1=pd.DataFrame(dict)

# %%
df1
# Out:
#     name  rno  age      place
# 0   siri  522   21    Narspur
# 1  deepu  530   22   tatipaka
# 2  keeru  511   23  manepalli
# 3   hari  541   24    Narspur

# %%
df1.iloc[1]
# Out:
# name        deepu
# rno           530
# age            22
# place    tatipaka
# Name: 1, dtype: object

# %%
import numpy as np
df1.iloc[1][1]=np.nan

# %%
df1
# Out:
#     name  rno age      place
# 0   siri  522  21    Narspur
# 1  deepu  NaN  22   tatipaka
# 2  keeru  511  23  manepalli
# 3   hari  541  24    Narspur

# %%
df1.isna().sum()
# Out:
# name     0
# rno      1
# age      0
# place    0
# dtype: int64

# %%
df1.isnull().sum()
# Out:
# name     0
# rno      1
# age      0
# place    0
# dtype: int64

# %%
df1.reindex([1,3,0,2])
# Out:
#     name  rno age      place
# 1  deepu  NaN  22   tatipaka
# 3   hari  541  24    Narspur
# 0   siri  522  21    Narspur
# 2  keeru  511  23  manepalli

# %%
df1.iloc[:,:][df1.age>21]
# Out:
#     name  rno  age      place
# 1  deepu  530   22   tatipaka
# 2  keeru  511   23  manepalli
# 3   hari  541   24    Narspur

# %%
df1.iloc[:-1]
# Out:
#     name  rno  age      place
# 0   siri  522   21    Narspur
# 1  deepu  530   22   tatipaka
# 2  keeru  511   23  manepalli

# %%
df2=dict1={'name':['rammi','devi','stephi','abc'],'rno':['539','543','556','22'],'age':[25,26,27,11],'place':['Narspuram','aka','palli','gbh']}

# %%
df2=pd.DataFrame(dict1)

# %%
df2
# Out:
#      name  rno  age      place
# 0   rammi  539   25  Narspuram
# 1    devi  543   26        aka
# 2  stephi  556   27      palli
# 3     abc   22   11        gbh

# %%
df2.merge(df1)
# Out:
# Empty DataFrame
# Columns: [name, rno, age, place]
# Index: []

# %%
pd.concat(df1,df2)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-90-16e2cecd5444> in <module>
# ----> 1 pd.concat(df1,df2)
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\reshape\concat.py in concat(objs, axis, join, join_axes, ignore_index, keys, levels, names, verify_integrity, sort, copy)
#     226                        keys=keys, levels=levels, names=names,
#     227                        verify_integrity=verify_integrity,
# --> 228                        copy=copy, sort=sort)
#     229     return op.get_result()
#     230
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\reshape\concat.py in __init__(self, objs, axis, join, join_axes, keys, levels, names, ignore_index, verify_integrity, copy, sort)
#     242             raise TypeError('first argument must be an iterable of pandas '
# ...

# %%
frames = [df1, df2]
result = pd.concat(frames)

# %%
result
# Out:
#      name  rno  age      place
# 0    siri  522   21    Narspur
# 1   deepu  530   22   tatipaka
# 2   keeru  511   23  manepalli
# 3    hari  541   24    Narspur
# 0   rammi  539   25  Narspuram
# 1    devi  543   26        aka
# 2  stephi  556   27      palli
# 3     abc   22   11        gbh

# %%
final=df1+df2

# %%
final['total']=final.age

# %%
final
# Out:
#           name     rno  age             place  total
# 0    sirirammi  522539   46  NarspurNarspuram     46
# 1    deepudevi  530543   48       tatipakaaka     48
# 2  keerustephi  511556   50    manepallipalli     50
# 3      hariabc   54122   35        Narspurgbh     35

# %%
df1.add(df2)
# Out:
#           name     rno  age             place
# 0    sirirammi  522539   46  NarspurNarspuram
# 1    deepudevi  530543   48       tatipakaaka
# 2  keerustephi  511556   50    manepallipalli
# 3      hariabc   54122   35        Narspurgbh

# %%
df1.dtypes
# Out:
# name     object
# rno      object
# age       int64
# place    object
# dtype: object

# %%
df1.add(df2,fill_value=1)
# Out:
#           name     rno  age             place
# 0    sirirammi  522539   46  NarspurNarspuram
# 1    deepudevi  530543   48       tatipakaaka
# 2  keerustephi  511556   50    manepallipalli
# 3      hariabc   54122   35        Narspurgbh

# %%
df1=pd.DataFrame(np.arange(12).reshape(3,4),columns=list("abcd"))

# %%
df1
# Out:
#    a  b   c   d
# 0  0  1   2   3
# 1  4  5   6   7
# 2  8  9  10  11

# %%
df2=pd.DataFrame(np.arange(20).reshape(4,5),columns=list("abcde"))

# %%
df2
# Out:
#     a   b   c   d   e
# 0   0   1   2   3   4
# 1   5   6   7   8   9
# 2  10  11  12  13  14
# 3  15  16  17  18  19

# %%
df1.add(df2,fill_value=1)
# Out:
#     a   b   c   d   e
# 0   0   2   4   6   8
# 1  10  12  14  16  18
# 2  20  22  24  26  28
# 3  30  32  34  36  38

# %%
import pandas as pd
dict={'name':['siri','deepu','keeru','hari','fg','jk','kjh'],'rno':['522','530','511','541','22','34','43'],'age':[np.nan,21,np.nan,22,23,np.nan,24],'place':['Narspur','tatipaka','manepalli','Narspur','ghj','mnv','klj']}

# %%
df1=pd.DataFrame(dict)

# %%
df1
# Out:
#     name  rno   age      place
# 0   siri  522   NaN    Narspur
# 1  deepu  530  21.0   tatipaka
# 2  keeru  511   NaN  manepalli
# 3   hari  541  22.0    Narspur
# 4     fg   22  23.0        ghj
# 5     jk   34   NaN        mnv
# 6    kjh   43  24.0        klj

# %%
df1.fillna(method='ffill',axis=0)
# Out:
#     name  rno   age      place
# 0   siri  522   NaN    Narspur
# 1  deepu  530  21.0   tatipaka
# 2  keeru  511  21.0  manepalli
# 3   hari  541  22.0    Narspur
# 4     fg   22  23.0        ghj
# 5     jk   34  23.0        mnv
# 6    kjh   43  24.0        klj

# %%
df1=pd.DataFrame(np.arange(12).reshape(3,4),columns=list("abcd"))
df1
# Out:
#    a  b   c   d
# 0  0  1   2   3
# 1  4  5   6   7
# 2  8  9  10  11

# %%
df1.replace({0:10,2:0})
# Out:
#     a  b   c   d
# 0  10  1   0   3
# 1   4  5   6   7
# 2   8  9  10  11

# %%
df1.sort_index()
# Out:
#    a  b   c   d
# 0  0  1   2   3
# 1  4  5   6   7
# 2  8  9  10  11

# %%
pd.read_csv("s.csv")
# Out:
#        Year Industry_aggregation_NZSIOC Industry_code_NZSIOC  \
# 0      2018                     Level 1                99999
# 1      2018                     Level 1                99999
# 2      2018                     Level 1                99999
# 3      2018                     Level 1                99999
# 4      2018                     Level 1                99999
# 5      2018                     Level 1                99999
# 6      2018                     Level 1                99999
# 7      2018                     Level 1                99999
# 8      2018                     Level 1                99999
# 9      2018                     Level 1                99999
# 10     2018                     Level 1                99999
# 11     2018                     Level 1                99999
# 12     2018                     Level 1                99999
# 13     2018                     Level 1                99999
# ...

# %%
df1=pd.DataFrame({"id":[1,2,3,4,5],"grade":['a','b','c','d','b']})

# %%
df1
# Out:
#    id grade
# 0   1     a
# 1   2     b
# 2   3     c
# 3   4     d
# 4   5     b

# %%
df1["Grade"]=df1["grade"].astype("category")
df1["Grade"].cat.categories=["very good","good","bad","very bad"]
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-141-d8d61aa9aa94> in <module>
#       1 df1["grade"]=df1["grade"].astype("category")
# ----> 2 df1["grade"].cat.categories=["very good","good","bad","very bad","bbad"]
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\base.py in __setattr__(self, key, value)
#     153             raise AttributeError("You cannot add any new attribute '{key}'".
#     154                                  format(key=key))
# --> 155         object.__setattr__(self, key, value)
#     156
#     157
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\accessor.py in _setter(self, new_values)
#      78
#      79             def _setter(self, new_values):
# ---> 80                 return self._delegate_property_set(name, new_values)
#      81
#      82             _getter.__name__ = name
#
# ...
