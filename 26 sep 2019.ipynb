# %%
# %matplotlib notebook
import matplotlib.pyplot as plt
import numpy as np

# %%
plt.figure()
plt.subplot(1,2,2)
linear_data=np.array([1,2,3,4,5,6,7,8])
plt.plot(linear_data,'-o')

# %%
left=np.array([1,3,5])
right=np.array([2,4,6])
plt.figure()
plt.subplot(1,2,1)
plt.plot(left,'-o')
plt.subplot(1,2,2)
plt.plot(right,'-o')

# %%
left=np.array([1,3,5])
right=np.array([2,4,6])
plt.figure()
plt.subplot(2,2,1)
plt.plot(left,'-o')
plt.subplot(2,2,2)
plt.plot(right,'-o')

# %%
plt.figure()
ax1=plt.subplot(1,2,1)
plt.plot([1,2,3],np.array([50,60,70]),'-o')
ax2=plt.subplot(1,2,2,sharey=ax1)
plt.plot([1,2,3],np.array([50,30,40]),'-x')

# %%
fig, ((ax1,ax2,ax3),(ax4,ax5,ax6),(ax7,ax8,ax9))=plt.subplots(3,3,sharex=True , sharey=True)
ax5.plot(linear_data,'-')

# %%
plt.figure()
linear_data=np.array([10,20,30,40])
xvals=range(len(linear_data))
plt.bar(xvals,linear_data,width=0.3)

# %%
plt.figure()
linear_data=np.array([10,20,30,40])
xvals=range(len(linear_data))
plt.barh(xvals,linear_data,height=0.3)

# %%
marks=[50,60,70,50,50,30,50,70,50]
plt.figure()
plt.hist(marks)

# %%
height_men_at_20=[4,5,4,5,5,6,7]

# %%
plt.figure()
_=plt.boxplot(height_men_at_20,whis='range')

# %%
import matplotlib.animation as animation
n=100
x=np.random.randn(n)
x
# Out:
# array([ 0.57547482, -1.16525865, -1.17154531, -0.2195344 , -1.01863306,
#        -0.90907893, -1.01670525, -0.01862088,  1.17770357, -0.5153208 ,
#         0.52883774, -1.27484083, -0.50867929, -1.08198685,  0.83312987,
#        -1.86930741, -0.19437033,  0.38961268, -1.5524381 , -0.41143405,
#         0.6848665 ,  0.27156978,  0.13021918,  2.05436938, -1.76151399,
#         0.37179942,  0.37107152, -0.25183965,  0.30125668, -1.17954923,
#         1.16002317, -1.11626225, -0.93516037, -1.8061348 ,  0.79641262,
#         1.33679005,  0.86409418, -0.96036341,  0.43093908,  0.97142075,
#        -0.76517614, -0.9833703 ,  0.06277027, -0.36879067, -1.57989152,
#         0.46190475, -0.35232703,  0.93921377,  1.10529794,  2.13683406,
#         0.74777388, -0.94847368, -0.33865946, -0.50942643, -0.39823525,
#        -0.59332997, -0.32504959, -2.86252002,  0.58797911, -0.67242845,
#        -1.47897322, -0.43170297, -0.79413449,  1.33760067,  0.89755437,
#         0.27139763, -1.19564148,  0.96271356, -0.30357289, -0.00913011,
#         0.51442818, -0.44498396,  0.72261421,  0.11978967,  0.40848615,
#        -0.17168356,  0.31063416,  1.9504705 , -0.32841655, -0.88739766,
#        -0.06004859,  0.09673566,  1.74145967, -1.85606272, -1.98318592,
#         0.41617281, -0.78438273,  0.16346292, -0.86529318,  0.50005829,
#         0.69560745, -2.90469122,  1.36847164,  1.08789854, -0.22113553,
#        -0.24125663, -0.10583269,  0.33694411,  2.2418059 , -0.46202189])

# %%
def update(curr):
    if curr==n:
        a.event_source.stop()
    plt.cla()
    bins=np.arange(-4,4,0.5)
    plt.hist(x[:curr],bins=bins)
    plt.axis([-4,4,0,30])
    plt.gca().set_title('Sample the normal distribution')
    plt.gca().set_ylabel('Frequency')
    plt.gca().set_xlabel('Value')
    plt.annotate('n={}'.format(curr),[3,27])

# %%
fig=plt.figure()
a=animation.FuncAnimation(fig,update,interval=100)
# Out:
# <img src="data:image/png;base64,..." width="606.3157970819448">

# %%
plt.figure()
data=np.random.rand(10)
plt.plot(data)
def onclick(event):
    plt.cla()
    plt.plot(data)
    plt.gca().set_title('Event at pixels {},{} \nand data {},{}'.format(event.x,event.y,event.xdata,event.ydata))
plt.gcf().canvas.mpl_connect('button_press_event',onclick)
# Out:
# <img src="data:image/png;base64,..." width="606.3157970819448">
# 6

# %%
# %matplotlib notebook
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
fruits=pd.read_table('fruit_data_with_colors.txt')
fruits.head()
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:6: FutureWarning: read_table is deprecated, use read_csv instead, passing sep='\t'.
#    fruit_label fruit_name fruit_subtype  mass  width  height  color_score
# 0            1      apple  granny_smith   192    8.4     7.3         0.55
# 1            1      apple  granny_smith   180    8.0     6.8         0.59
# 2            1      apple  granny_smith   176    7.4     7.2         0.60
# 3            2   mandarin      mandarin    86    6.2     4.7         0.80
# 4            2   mandarin      mandarin    84    6.0     4.6         0.79
